# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Clinic_sales.csv')
df.head(5)
# Out:
#          DATE  HAIR  SKIN  TOTAL SALES
# 0  01-03-2024  1000   500         1500
# 1  02-03-2024   800  1200         2000
# 2  03-03-2024   900  1300         2200
# 3  04-03-2024  2700  1000         3700
# 4  05-03-2024   600   900         1500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         153 non-null    object
#  1   HAIR         153 non-null    int64
#  2   SKIN         153 non-null    int64
#  3   TOTAL SALES  153 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 4.9+ KB

# %%
df.isna().sum()
# Out:
# DATE           0
# HAIR           0
# SKIN           0
# TOTAL SALES    0
# dtype: int64

# %%
df.describe()
# Out:
#                HAIR          SKIN   TOTAL SALES
# count    153.000000    153.000000    153.000000
# mean    3788.888889   3991.176471   7780.065359
# std     3238.350692   3637.338881   5875.835159
# min        0.000000      0.000000   1200.000000
# 25%     1200.000000   1650.000000   3000.000000
# 50%     2500.000000   2700.000000   6250.000000
# 75%     5600.000000   5000.000000  11300.000000
# max    14800.000000  19000.000000  25900.000000

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='DATE', y='TOTAL SALES', data=df, marker='o')
plt.title('Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.bar(df['SKIN'],df['HAIR'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='DATE', y='HAIR', data=df, marker='o', label='Hair Sales')
sns.lineplot(x='DATE', y='SKIN', data=df, marker='o', label='Skin Sales')
plt.title('Hair and Skin Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.figure(figsize=(14, 7))

# Plot Hair Sales
plt.plot( df['HAIR'], label='Hair Sales', color='blue', linestyle='-', marker='o')

# Plot Skin Sales
plt.plot( df['SKIN'], label='Skin Sales', color='green', linestyle='--', marker='x')

# Formatting the plot
plt.title('Daily Sales of Hair and Skin Division', fontsize=16)
# plt.xlabel( fontsize=14)
plt.ylabel('Sales ', fontsize=14)
plt.legend()
plt.grid(True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['HAIR', 'SKIN', 'TOTAL SALES']])
plt.title('Boxplot of Sales Data')
plt.ylabel('Sales')
plt.show()
# Out:
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import matplotlib.pyplot as plt

a=plt.plot(df["DATE"],df['HAIR'])
plt.xlabel("Date")
plt.ylabel("Hair")
plt.show()

# %%
import matplotlib.pyplot as plt

b=plt.plot(df["DATE"],df['SKIN'])
plt.xlabel("Date")
plt.ylabel("skin")
plt.show()

# %%
import matplotlib.pyplot as plt

c=plt.plot(df["DATE"],df['TOTAL SALES'])
plt.xlabel("Date")
plt.ylabel("Total sales")
plt.show()

# %%
data= df.set_index("DATE",inplace=False)
data.head(5)
# Out:
#             HAIR  SKIN  TOTAL SALES    Lag1
# DATE
# 2024-03-04  2700  1000         3700  2200.0
# 2024-03-05   600   900         1500  3700.0
# 2024-03-06  1200  1800         3000  1500.0
# 2024-03-07  1100  1650         2750  3000.0
# 2024-03-08  1300  1950         3250  2750.0

# %%
plt.plot(data['TOTAL SALES'])
plt.title("line plot")
plt.show()

# %%
import statsmodels.api 
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    print("result of dickey fuller test:")
    dftest= adfuller(timeseries,autolag='AIC')
    dfoutput= pd.Series(dftest[0:4],index=["test statistic","p value","#lags used","number of observations"])
    for key, value in dftest[4].items():
        dfoutput["critical value (%s)"%key]= value
    print(dfoutput)
adf_test(data['TOTAL SALES'])
# Out:
# result of dickey fuller test:
# test statistic             -0.334759
# p value                     0.920435
# #lags used                 10.000000
# number of observations    139.000000
# critical value (1%)        -3.478294
# critical value (5%)        -2.882568
# critical value (10%)       -2.577983
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

movingAverage = data['TOTAL SALES'].rolling(window=10).mean()  # Calculate the rolling mean
movingSTD = data['TOTAL SALES'].rolling(window=10).std()       # Calculate the rolling standard deviation

plt.figure(figsize=(12, 6))
plt.plot(data['TOTAL SALES'], color="black", label="Original Value")
plt.plot(movingAverage, color="yellow", label="Moving Mean")
plt.plot(movingSTD, color="blue", label="Moving Standard Deviation")
plt.legend(loc="best")
plt.title("Moving Mean and Standard Deviation")
plt.show()

# %%
import numpy as np

# %%
data["log_value"]= np.log(data["TOTAL SALES"])
data
# Out:
#              HAIR  SKIN  TOTAL SALES     Lag1  log_value
# DATE
# 2024-03-04   2700  1000         3700   2200.0   8.216088
# 2024-03-05    600   900         1500   3700.0   7.313220
# 2024-03-06   1200  1800         3000   1500.0   8.006368
# 2024-03-07   1100  1650         2750   3000.0   7.919356
# 2024-03-08   1300  1950         3250   2750.0   8.086410
# ...           ...   ...          ...      ...        ...
# 2024-07-27   8000  5600        13600  20200.0   9.517825
# 2024-07-28  11200  7200        18400  13600.0   9.820106
# 2024-07-29  14800  5600        20400  18400.0   9.923290
# 2024-07-30   2800  5400         8200  20400.0   9.011889
# 2024-07-31   3000  4300         7300   8200.0   8.895630
#
# [150 rows x 5 columns]

# %%
data["log_diff"]= data["log_value"] - data['log_value'].shift(1)
data
# Out:
#              HAIR  SKIN  TOTAL SALES     Lag1  log_value  log_diff
# DATE
# 2024-03-04   2700  1000         3700   2200.0   8.216088       NaN
# 2024-03-05    600   900         1500   3700.0   7.313220 -0.902868
# 2024-03-06   1200  1800         3000   1500.0   8.006368  0.693147
# 2024-03-07   1100  1650         2750   3000.0   7.919356 -0.087011
# 2024-03-08   1300  1950         3250   2750.0   8.086410  0.167054
# ...           ...   ...          ...      ...        ...       ...
# 2024-07-27   8000  5600        13600  20200.0   9.517825 -0.395613
# 2024-07-28  11200  7200        18400  13600.0   9.820106  0.302281
# 2024-07-29  14800  5600        20400  18400.0   9.923290  0.103184
# 2024-07-30   2800  5400         8200  20400.0   9.011889 -0.911401
# 2024-07-31   3000  4300         7300   8200.0   8.895630 -0.116260
#
# [150 rows x 6 columns]

# %%
movingAverage= data['log_diff'].rolling(window=12).mean()            #gives the mean value
movingSTD = data['log_diff'].rolling(window=12).std()
plt.plot(data['log_diff'])
plt.plot(movingAverage, label = "Moving Average")
plt.plot(movingSTD, label= "Moving STD")
plt.legend(loc="best")
plt.title("")
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data['log_value'],model="additive",period=30)
decomposition.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data['log_value'],model="multiplicative",period=30)
decomposition.plot()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA


ts_log = np.log(df['TOTAL SALES']).diff().dropna()
model1= ARIMA(ts_log, order=(2,1,2))
result= model1.fit()

plt.plot(ts_log)
plt.plot(result.fittedvalues, color= 'red')
plt.title("residual sums: %4f" %sum((result.fittedvalues-ts_log)**2))
print("plotting AR model")
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# plotting AR model

# %%
ts_log = np.log(df['TOTAL SALES']).diff().dropna()
model1= ARIMA(ts_log, order=(2,0,2))
result= model1.fit()

plt.plot(ts_log)
plt.plot(result.fittedvalues, color= 'red')
plt.title("residual sums: %4f" %sum((result.fittedvalues-ts_log)**2))
print("plotting AR model")
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# plotting AR model

# %%
ts_log = np.log(df['TOTAL SALES']).diff().dropna()
model1= ARIMA(ts_log, order=(0,1,2))
result= model1.fit()

plt.plot(ts_log)
plt.plot(result.fittedvalues, color= 'red')
plt.title("residual sums: %4f" %sum((result.fittedvalues-ts_log)**2))
print("plotting AR model")
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# plotting AR model

# %%
ts_log = np.log(df['']).diff().dropna()
model1= ARIMA(ts_log, order=(2,1,0))
result= model1.fit()

plt.plot(ts_log)
plt.plot(result.fittedvalues, color= 'red')
plt.title("residual sums: %4f" %sum((result.fittedvalues-ts_log)**2))
print("plotting AR model")
# Out:
# plotting AR model
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
ts_log = np.log(data['TOTAL SALES']).diff().dropna()
order = (2, 1, 2)  
seasonal_order = (2, 1, 2, 9)  # Example seasonal parameters
sarima_model = SARIMAX(ts_log, order=order, seasonal_order=seasonal_order)
result = sarima_model.fit()


plt.plot(ts_log)
plt.plot(result.fittedvalues, color= 'red')
plt.title("residual sums: %4f" %sum((result.fittedvalues-ts_log)**2))
print("plotting AR model")
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# plotting AR model

# %%
# Forecast for the next 24 months
model = ARIMA(data['log_value'], order=(2, 0, 2))
model_fit = model.fit()
forecast_steps = 30
forecast = model_fit.get_forecast(steps=forecast_steps)

# Confidence intervals
forecast_ci = forecast.conf_int()

# Plotting forecast
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['TOTAL SALES'], label='Original')
plt.plot(forecast.predicted_mean.index, forecast.predicted_mean, color='red', label='Forecast')
plt.fill_between(forecast_ci.index, forecast_ci.iloc[:, 0], forecast_ci.iloc[:, 1], color='pink', alpha=0.2)
plt.title('ARIMA Forecast of Total sales for Next 1 Month')
plt.xlabel('Days')
plt.ylabel('Total sales')
plt.legend()
plt.grid(True)
plt.show()

# Forecasted values table
forecast_values = forecast.predicted_mean[-forecast_steps:].round(2)
forecast_data = pd.DataFrame({'ARIMA Forecast of Total sales for Next 1 Month': forecast_values})
print(forecast_data)
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
model_sarima = SARIMAX(data['log_value'], order=(2, 1, 2), seasonal_order=(2, 1, 2, 9))
model_sarima_fit = model_sarima.fit()
forecast_sarima = model_sarima_fit.get_forecast(steps=forecast_steps)
forecast_sarima_ci = forecast_sarima.conf_int()

plt.figure(figsize=(12, 8))
plt.plot(data.index, data['log_value'], label='Original')
plt.plot(forecast_sarima.predicted_mean.index, forecast_sarima.predicted_mean, color='red', label='SARIMA Forecast')
plt.fill_between(forecast_sarima_ci.index, forecast_sarima_ci.iloc[:, 0], forecast_sarima_ci.iloc[:, 1], color='lightblue', alpha=0.2)
plt.title('SARIMA Forecast of Total sales for Next 1 Month')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

#forecasted values table for SARIMA
forecast_sarima_values = forecast_sarima.predicted_mean.round(2)
forecast_sarima_data = pd.DataFrame({'Forecasted values': forecast_sarima_values})
print("SARIMA Forecasted Values:")
print(forecast_sarima_data)
# Out:
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA Forecasted Values:
#             Forecasted values
# 2024-08-01               9.42
# 2024-08-02              10.00
# 2024-08-03               9.58
# 2024-08-04               9.20
# 2024-08-05               9.24
# 2024-08-06               9.92
# 2024-08-07               9.64
# 2024-08-08               9.46
# 2024-08-09               9.62
# 2024-08-10               9.36
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM


# Select the 'TOTAL SALES' column for time series forecasting
series = data['log_value'].values.reshape(-1, 1)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
series_scaled = scaler.fit_transform(series)

# Prepare the dataset for LSTM
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step), 0]
        X.append(a)
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 10  # Number of past days to consider for predicting the next
X, y = create_dataset(series_scaled, time_step)

# Reshape input to be [samples, time steps, features] which is required for LSTM
X = X.reshape(X.shape[0], X.shape[1], 1)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=1, epochs=20)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform to get actual values
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(series, label='Original Data')
plt.plot(np.arange(time_step, time_step + len(train_predict)), train_predict, label='Train Predictions', color='blue')
plt.plot(np.arange(len(series) - len(test_predict), len(series)), test_predict, label='Test Predictions', color='red')
plt.legend()
plt.title('LSTM Model Forecast')
plt.show()
# Out:
# Epoch 1/20
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1011
# Epoch 2/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0595
# Epoch 3/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0382
# Epoch 4/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0515
# Epoch 5/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0414
# Epoch 6/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0491
# Epoch 7/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0415
# Epoch 8/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0499
# Epoch 9/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0461
# Epoch 10/20
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0402
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and 'TOTAL SALES' is the column you're forecasting

# Create lag features
data['Lag1'] = data['TOTAL SALES'].shift(2)
data = data.dropna()

# Split into features and target
X = data[['Lag1']]
y = data['TOTAL SALES']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Fit the Random Forest model
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)

# Calculate accuracy metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Print the predicted values and accuracy metrics
print("Predicted values:", predictions)
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Plotting
plt.plot(y_test.index, y_test, label='Original')
plt.plot(y_test.index, predictions, label='Predicted', color='red')
plt.legend()
plt.title('Random Forest Regressor Forecast')
# plt.xlabel("days")
plt.show()
# Out:
# Predicted values: [ 4463.29761905  7996.23333333  4939.          8895.
#  10596.          4795.5         8895.          6337.26111111
#  12560.86666667  4939.         12359.78333333 10318.
#   9517.          4795.5        12039.37460317  8979.
#   7957.23333333  4748.12896825  4786.          8979.
#   8587.5         8979.          8587.5         8979.
#   9517.          7609.75        8979.          4982.8
#   7609.75      ]
# Mean Absolute Error (MAE): 7216.78
# Mean Squared Error (MSE): 72990362.63
# R-squared (R²): -0.70

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'TOTAL SALES' is the column you're forecasting

# Create lag features
df['Lag1'] = df['TOTAL SALES'].shift(1)
df = df.dropna()

# Split into features and target
X = df[['Lag1']]
y = df['TOTAL SALES']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Fit the XGBoost model
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100)
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)

# Calculate accuracy metrics
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Print the predicted values and accuracy metrics
print("Predicted values:", predictions)
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Plotting
plt.plot(y_test.index, y_test, label='Original')
plt.plot(y_test.index, predictions, label='Predicted', color='red')
plt.legend()
plt.title('XGBoost Model Forecast')
plt.show()
# Out:
# Predicted values: [ 4003.478   4516.9365  4717.78    4717.78   12484.426   4707.0537
#   4717.78    3552.649   4899.2656  4717.78    7574.9824  3530.4885
#  10998.829   4707.0537  6697.6504  4717.78   10394.908   4357.8184
#   8205.125   4717.78   10297.319   4717.78   10297.319   4717.78
#  10998.829   8205.125   4717.78   25880.66    8205.125   4585.8853]
# Mean Squared Error (MSE): 80714588.21
# R-squared (R²): -0.94

# %%
import pandas as pd
from prophet import Prophet

# Prepare the data
df['DATE'] = pd.to_datetime(df['DATE'], format='%d-%m-%Y')

data = df.rename(columns={'DATE': 'date', 'TOTAL SALES': 'sale'})
# df['DATE'] = pd.to_datetime(df['DATE'], format='%d-%m-%Y')
# Check for NaNs
print(data.isna().sum())  # This will show how many NaNs are in each column

# Handle NaNs
data = data.dropna()  # Drop rows with NaNs

# Initialize and fit the model
model = Prophet()
model.fit(data)

# Make future predictions
future = model.make_future_dataframe(periods=30)  # Extend this as needed
forecast = model.predict(future)

# Print the predictions
# Plot the forecast
model.plot(forecast)
plt.title("Prophet Model Prediction")
plt.show()

# If you want to evaluate accuracy (assuming you have actual values to compare with)
# For demonstration purposes, we will calculate accuracy on the in-sample data.
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE, MSE, and R²
mae = mean_absolute_error(data['sale'], forecast['yhat'][:len(data)])
mse = mean_squared_error(data['sale'], forecast['yhat'][:len(data)])
r2 = r2_score(data['sale'], forecast['yhat'][:len(data)])

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# date    0
# HAIR    0
# SKIN    0
# sale    0
# Lag1    0
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[163], line 17
#      15 # Initialize and fit the model
#      16 model = Prophet()
# ---> 17 model.fit(data)
#      19 # Make future predictions
#      20 future = model.make_future_dataframe(periods=30)  # Extend this as needed
#
# File c:\Python312\Lib\site-packages\prophet\forecaster.py:1217, in Prophet.fit(self, df, **kwargs)
#    1213 if self.history is not None:
#    1214     raise Exception('Prophet object can only be fit once. '
#    1215                     'Instantiate a new object.')
# -> 1217 model_inputs = self.preprocess(df, **kwargs)
#    1218 initial_params = self.calculate_initial_params(model_inputs.K)
#    1220 dat = dataclasses.asdict(model_inputs)
#
# ...

# %%
import pmdarima as pm
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Assuming df is your DataFrame and 'TOTAL SALES' is your target variable

# Split the data into training and testing sets
train_size = int(len(df) * 0.8)  # 80% for training
train, test = df['TOTAL SALES'][:train_size], df['TOTAL SALES'][train_size:]

# Fit the model on the training set
model = pm.auto_arima(train, seasonal=True, m=12, trace=True)

# Make predictions on the test set
forecast = model.predict(n_periods=len(test))  # Forecast the same length as test set

# Calculate accuracy metrics
mae = mean_absolute_error(test, forecast)
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)

# Print the forecast and accuracy
print("Forecasted values:")
print(forecast)
print("\nAccuracy Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

# Plot the forecast
plt.figure(figsize=(10, 6))
plt.plot(df['TOTAL SALES'], label='Original')
plt.plot(range(train_size, len(df)), forecast, label='Forecast', color='red')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2445.859, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2426.909, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2443.874, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2425.008, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=2426.826, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=2424.364, Time=0.20 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=2424.014, Time=0.30 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=2424.395, Time=0.14 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=2425.957, Time=0.54 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=2424.054, Time=0.32 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=2445.465, Time=0.13 sec
# ...
